# %%
# import libraries and data

import pandas as pd
import os
import numpy as np

# depending on the OS the path to the data file is different
if os.name == 'nt':
    data = pd.read_excel(r'..\data\nutrient-file-release2-jan22.xlsx', sheet_name='All solids & liquids per 100g')
elif os.name == 'posix':
    data = pd.read_excel(r'../data/nutrient-file-release2-jan22.xlsx', sheet_name='All solids & liquids per 100g')

# print first 5 results.
data.head()
# Out:
#   Public Food Key  Classification                      Food Name
# 0         F002258         31302.0   Cardamom seed, dried, ground  \
# 1         F002893         31302.0  Chilli (chili), dried, ground
# 2         F002963         31302.0        Cinnamon, dried, ground
# 3         F002970         31302.0          Cloves, dried, ground
# 4         F003190         31302.0  Coriander seed, dried, ground
#
#    Energy with dietary fibre, equated \n(kJ)
# 0                                       1236  \
# 1                                       1280
# 2                                       1004
# 3                                       1389
# 4                                       1344
#
#    Energy, without dietary fibre, equated \n(kJ)  Moisture (water) \n(g)
# 0                                           1012                     8.3  \
# 1                                           1002                    10.8
# 2                                            579                    10.6
# 3                                           1118                     9.9
# 4                                           1009                     8.9
#
#    Protein \n(g)  Nitrogen \n(g)  Fat, total \n(g)  Ash \n(g)  ...
# 0           10.8            1.72               6.7        5.8  ...  \
# 1           13.4            2.14              14.3       11.8  ...
# 2            4.0            0.64               1.2        3.6  ...
# 3            6.0            0.96              13.0        5.6  ...
# 4           12.4            1.98              17.8        6.0  ...
#
#    Leucine \n(mg)  Lysine \n(mg)  Methionine \n(mg)  Phenylalanine \n(mg)
# 0             NaN            NaN                NaN                   NaN  \
# 1             NaN            NaN                NaN                   NaN
# 2             NaN            NaN                NaN                   NaN
# 3             NaN            NaN                NaN                   NaN
# 4             NaN            NaN                NaN                   NaN
#
#    Proline \n(mg)  Serine \n(mg)  Threonine \n(mg)  Tyrosine \n(mg)
# 0             NaN            NaN               NaN              NaN  \
# 1             NaN            NaN               NaN              NaN
# 2             NaN            NaN               NaN              NaN
# 3             NaN            NaN               NaN              NaN
# 4             NaN            NaN               NaN              NaN
#
#    Tryptophan \n(mg)  Valine \n(mg)
# 0                155            NaN
# 1                 69            NaN
# 2                 49            NaN
# 3                 30            NaN
# 4                178            NaN
#
# [5 rows x 293 columns]

# %%
# plot on a graph the number of rows with the same classification value and do not include x-axis marks
data['Classification'].value_counts().plot(kind='bar', title='Number of rows per classification').tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# %%
# convert classification to food group defined as taking the slice of the string for first 3 characters
data['Classification'] = data['Classification'].astype(str).str.slice(0, 3)

# print the total number of classifications
print('Total number of classifications: ' + str(len(data['Classification'].unique())))

# plot on a graph the number of rows with the same food group value and do not include x-axis marks
data['Classification'].value_counts().plot(kind='bar', title='Number of rows per food group').tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
# Out:
# Total number of classifications: 106
